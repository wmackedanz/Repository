# %%
import polars as pl

# %%
batting = pl.read_csv("./Repository/data/lahman_1871-2023_csv/Batting.csv")
batting.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 batting = pl.read_csv("./Repository/data/lahman_1871-2023_csv/Batting")
#
# File ~\Downloads\anaconda\envs\Polars\Lib\site-packages\polars\_utils\deprecation.py:91, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      86 @wraps(function)
#      87 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
#      88     _rename_keyword_argument(
#      89         old_name, new_name, kwargs, function.__qualname__, version
#      90     )
# ---> 91     return function(*args, **kwargs)
#
# File ~\Downloads\anaconda\envs\Polars\Lib\site-packages\polars\_utils\deprecation.py:91, in deprecate_renamed_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      86 @wraps(function)
#      87 def wrapper(*args: P.args, **kwargs: P.kwargs) -> T:
# ...
